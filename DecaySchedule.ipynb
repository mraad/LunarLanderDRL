# %%
import matplotlib.pyplot as plt
 
from rl.utils import Utils

# %%
# %matplotlib inline

# %%
eps = Utils.decay_schedule(1.0, 0.1, 0.6, 100)

plt.xlabel("Episodes")
plt.ylabel("Eps")
ax = plt.plot(eps)
