# %%
import matplotlib.pyplot as plt
 
from rl.utils import Utils

# %%
# %matplotlib inline

# %%
eps = Utils.dec_schedule(1.0, 0.1, 0.25, 500)

plt.xlabel("Episodes")
plt.ylabel("Eps")
ax = plt.plot(eps)
